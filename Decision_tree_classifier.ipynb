# %%
# Importing libraries in Python
import sklearn.datasets as datasets
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,confusion_matrix
from sklearn.metrics import accuracy_score

# Loading the iris dataset
data=pd.read_csv("Iris.csv")

# %%
# Defining x with independent variables
x=data.iloc[:,1:5]
print(x.head(5))
# Out:
#    SepalLength(cm)  SepalWidth(cm)  PetalLength(cm)  PetalWidth(cm)
# 0              5.1             3.5              1.4             0.2
# 1              4.9             3.0              1.4             0.2
# 2              4.7             3.2              1.3             0.2
# 3              4.6             3.1              1.5             0.2
# 4              5.0             3.6              1.4             0.2

# %%
#Defning y with dependent variable(i.e.,species)
y=data.iloc[:,5]
print(y)
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: Species, Length: 150, dtype: object

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.30)

# %%
# Defining the decision tree algorithm
dtree=DecisionTreeClassifier()
dtree.fit(X_train,y_train)

print('Decision Tree Classifer Created')
# Out:
# Decision Tree Classifer Created

# %%
# Import necessary libraries for graph viz
from sklearn.externals.six import StringIO  
from IPython.display import Image  
from sklearn.tree import export_graphviz
import pydotplus

# Visualize the graph
dot_data = StringIO()
export_graphviz(dtree, out_file=dot_data, feature_names=x.columns,class_names=['Setosa','Virginica','Versicolor'],  
                filled=True, rounded=True,
                special_characters=True)
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
Image(graph.create_png())

# %%
#Accuracy measures
print('DECISION TREE:\nConfusion Matrix:\n',confusion_matrix(y_test,predictions))
print('\nClassification Report:\n',classification_report(y_test,predictions))
print('Accuracy : ',accuracy_score(y_test, predictions)*100,'%')
# Out:
# DECISION TREE:
# Confusion Matrix:
#  [[17  0  0]
#  [ 0 14  0]
#  [ 0  1 13]]
#
# Classification Report:
#                   precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        17
# Iris-versicolor       0.93      1.00      0.97        14
#  Iris-virginica       1.00      0.93      0.96        14
#
#        accuracy                           0.98        45
#       macro avg       0.98      0.98      0.98        45
#    weighted avg       0.98      0.98      0.98        45
#
# Accuracy :  97.77777777777777 %

# %%
#Verification using new data input
pred_new=dtree.predict(np.array([[5.1,3.5,1.4,0.2]]))
print("Species identified from given data:",pred_new)
# Out:
# Species identified from given data: ['Iris-setosa']
